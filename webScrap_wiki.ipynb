# %% [markdown]
# 🧹 Web Scraping Workshop 🧹 - https://www.wikipedia.org/
#
# 7 January 2024 @Keerati-Deja
#
# 📝NOTE📝 Wikipedia is a static website which is easy to scrape.
#
# ⚠️Achtung!⚠️\
# Some codes may run error if there are changes within the website.\
# hint : maybe due to changes in some HTML tags\
# Figure it by yourself! 😈

# %% [markdown]
# <img src="wiki_0.jpg" />

# %%
#install library (just-in-case)

# !pip install bs4
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita'

# %%
data = requests.get(url)

# %%
pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita')
# Out:
# [                                                   0  \
#  0  .mw-parser-output .legend{page-break-inside:av...
#
#                                                     1  \
#  0  $20,000 - $30,000 $10,000 - $20,000 $5,000 - $...
#
#                                               2
#  0  $1,000 - $2,500 $500 - $1,000 <$500 No data  ,
#              Country/Territory UN Region Median esimate IMF[4][5]        \
#              Country/Territory UN Region Median esimate  Estimate  Year
#  0                         NaN       NaN            NaN       NaN   NaN
#  1                      Monaco    Europe       234317.0         —     —
#  2               Liechtenstein    Europe       176672.0         —     —
#  3                  Luxembourg    Europe       133745.0    135605  2023
#  4                     Bermuda  Americas       115750.0         —     —
#  ..                        ...       ...            ...       ...   ...
# ...

# %%
data_list_gdp = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita')

# %%
# from --> pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita') --> the wanted table is at the [1] position
data_list_gdp[1]
# Out:
#             Country/Territory UN Region Median esimate IMF[4][5]        \
#             Country/Territory UN Region Median esimate  Estimate  Year
# 0                         NaN       NaN            NaN       NaN   NaN
# 1                      Monaco    Europe       234317.0         —     —
# 2               Liechtenstein    Europe       176672.0         —     —
# 3                  Luxembourg    Europe       133745.0    135605  2023
# 4                     Bermuda  Americas       115750.0         —     —
# ..                        ...       ...            ...       ...   ...
# 219  Central African Republic    Africa          461.0       539  2023
# 220              Sierra Leone    Africa          461.0       415  2023
# 221               South Sudan    Africa          417.0       417  2023
# 222               Afghanistan      Asia          373.0       443  2021
# 223                   Burundi    Africa          246.0       246  2023
#
#     World Bank[6]       United Nations[7]
# ...
